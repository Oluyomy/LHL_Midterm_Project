# %%
# Libraries to work with dataframe
import json
import pandas as pd
import numpy as np
# Libraries for datetime
import datetime as dt
# Libraries for EDA
import matplotlib as plt
import seaborn as sns
# Libraries for ML
from sklearn import linear_model, datasets
import statsmodels.api as sm

# %%
# Load the data
df3=pd.read_csv(r'/Users/tinapham/Desktop/lighthouse-data-notes/ProJect/LHL_Midterm_Project/Data/Cleanjobdf/Cleanjobdf.csv', sep=",")
# Check dataset
df3.head()
# Out:
#          Time Time Code           Country Name Country Code  \
# 0  2000-01-01    YR2000          United States          USA
# 1  2000-01-01    YR2000         United Kingdom          GBR
# 2  2000-01-01    YR2000         European Union          EUU
# 3  2000-01-01    YR2000  Europe & Central Asia          ECS
# 4  2000-01-01    YR2000                 Canada          CAN
#
#    employer_pct_female  employer_pct_male  employer_pct_total  \
# 0             2.240000           5.507000            4.021000
# 1             1.672000           4.500000            3.212000
# 2             2.771487           6.901186            5.123410
# 3             2.444044           5.616116            4.226875
# 4             3.274000           7.503000            5.567000
#
#    industry_pct_female  industry_pct_male  industry_pct_total  ...  \
# 0            23.322001          12.174000           32.632000  ...
# 1            25.167000          11.953000           36.221001  ...
# 2            29.391753          16.766526           38.940407  ...
# 3            27.987970          17.433606           36.217034  ...
# 4            22.475000          11.167000           32.016998  ...
#
#    intermediate_education_pct_male  basic_education_pct_total  \
# 0                        65.277100                  28.297300
# 1                        82.661201                  63.468300
# 2                        69.643060                  34.678472
# 3                         0.000000                   0.000000
# 4                        70.049301                  42.889599
#
#    basic_education_pct_female  basic_education_pct_male  \
# 0                   51.912498                 40.087200
# 1                   76.823196                 69.078598
# 2                   55.798056                 43.627717
# 3                    0.000000                  0.000000
# 4                   60.496498                 51.746498
#
#    wages_and_salaries-pct_female  wages_and_salaries_pct_male  \
# 0                      91.585999                    86.290001
# 1                      92.141998                    83.941002
# 2                      85.157378                    79.046368
# 3                      81.372209                    77.657763
# 4                      87.636002                    80.613998
#
#    wages_and_salaries_pct_total  Laborforce_pop_total  Population_total  \
# 0                     88.699997           146767599.0       282162411.0
# 1                     87.676003            29295681.0        58892514.0
# 2                     81.677008           228526899.0       488178832.0
# 3                     79.284578           397686380.0       862304086.0
# 4                     83.828003            16235249.0        30769700.0
#
#    Population_density
# 0           30.797301
# 1          243.427909
# 2          115.084593
# 3           31.414610
# 4            3.383699
#
# [5 rows x 34 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Time                               221 non-null    object
#  1   Time Code                          221 non-null    object
#  2   Country Name                       221 non-null    object
#  3   Country Code                       221 non-null    object
#  4   employer_pct_female                221 non-null    float64
#  5   employer_pct_male                  221 non-null    float64
#  6   employer_pct_total                 221 non-null    float64
#  7   industry_pct_female                221 non-null    float64
#  8   industry_pct_male                  221 non-null    float64
#  9   industry_pct_total                 221 non-null    float64
#  10  service_pct_female                 221 non-null    float64
#  11  service_pct_male                   221 non-null    float64
#  12  service_pct_total                  221 non-null    float64
#  13  agriculture_pct_female             221 non-null    float64
#  14  agriculture_pct_male               221 non-null    float64
#  15  agriculture_pct_total              221 non-null    float64
#  16  laborforce_pct_female              221 non-null    float64
#  17  laborforce_pct_male                221 non-null    float64
#  18  laborforce_pct_total               221 non-null    float64
#  19  advance_education_pct_total        221 non-null    float64
#  20  advance_education_pct_female       221 non-null    float64
#  21  advance_education_pct_male         221 non-null    float64
#  22  intermediate_education_pct_total   221 non-null    float64
#  23  intermediate_education_pct_female  221 non-null    float64
#  24  intermediate_education_pct_male    221 non-null    float64
#  25  basic_education_pct_total          221 non-null    float64
#  26  basic_education_pct_female         221 non-null    float64
#  27  basic_education_pct_male           221 non-null    float64
#  28  wages_and_salaries-pct_female      221 non-null    float64
#  29  wages_and_salaries_pct_male        221 non-null    float64
#  30  wages_and_salaries_pct_total       221 non-null    float64
#  31  Laborforce_pop_total               221 non-null    float64
#  32  Population_total                   221 non-null    float64
#  33  Population_density                 221 non-null    float64
# dtypes: float64(30), object(4)
# memory usage: 58.8+ KB

# %%
# Create df_female with data from column 0 to 3
df_female = df3.iloc[:, 0:4]

# Create a gender column and fill in female
df_female['gender']= ["female" for i in range(len(df_female))]

# Filter all the column from df3 that has the word "female in column"
df_female=pd.concat([df_female, df3.filter(regex='female')], axis=1)

# All population info to female data frame
df_female= pd.concat([df_female, df3.iloc[:, 31:34]], axis=1)

df_female.head()
# Out:
#          Time Time Code           Country Name Country Code  gender  \
# 0  2000-01-01    YR2000          United States          USA  female
# 1  2000-01-01    YR2000         United Kingdom          GBR  female
# 2  2000-01-01    YR2000         European Union          EUU  female
# 3  2000-01-01    YR2000  Europe & Central Asia          ECS  female
# 4  2000-01-01    YR2000                 Canada          CAN  female
#
#    employer_pct_female  industry_pct_female  service_pct_female  \
# 0             2.240000            23.322001           74.844002
# 1             1.672000            25.167000           73.297997
# 2             2.771487            29.391753           62.666310
# 3             2.444044            27.987970           57.232973
# 4             3.274000            22.475000           74.237000
#
#    agriculture_pct_female  laborforce_pct_female  \
# 0                2.569000              59.022999
# 1                2.171000              53.554001
# 2                8.359486              47.703181
# 3               14.853220              48.672822
# 4                4.478000              58.647999
#
#    advance_education_pct_female  intermediate_education_pct_female  \
# 0                     84.552902                          73.584801
# 1                     92.156303                          86.192497
# 2                     82.319485                          75.869636
# 3                      0.000000                           0.000000
# 4                     82.825500                          77.127098
#
#    basic_education_pct_female  wages_and_salaries-pct_female  \
# 0                   51.912498                      91.585999
# 1                   76.823196                      92.141998
# 2                   55.798056                      85.157378
# 3                    0.000000                      81.372209
# 4                   60.496498                      87.636002
#
#    Laborforce_pop_total  Population_total  Population_density
# 0           146767599.0       282162411.0           30.797301
# 1            29295681.0        58892514.0          243.427909
# 2           228526899.0       488178832.0          115.084593
# 3           397686380.0       862304086.0           31.414610
# 4            16235249.0        30769700.0            3.383699

# %%
df_female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Time                               221 non-null    object
#  1   Time Code                          221 non-null    object
#  2   Country Name                       221 non-null    object
#  3   Country Code                       221 non-null    object
#  4   gender                             221 non-null    object
#  5   employer_pct_female                221 non-null    float64
#  6   industry_pct_female                221 non-null    float64
#  7   service_pct_female                 221 non-null    float64
#  8   agriculture_pct_female             221 non-null    float64
#  9   laborforce_pct_female              221 non-null    float64
#  10  advance_education_pct_female       221 non-null    float64
#  11  intermediate_education_pct_female  221 non-null    float64
#  12  basic_education_pct_female         221 non-null    float64
#  13  wages_and_salaries-pct_female      221 non-null    float64
#  14  Laborforce_pop_total               221 non-null    float64
#  15  Population_total                   221 non-null    float64
#  16  Population_density                 221 non-null    float64
# dtypes: float64(12), object(5)
# memory usage: 29.5+ KB

# %%
# Remove the word female to prepare to merge with male dataframe
df_female.columns = df_female.columns.str.replace("_female", '')
df_female.columns = df_female.columns.str.replace("-", '_')
df_female
# Out:
#            Time Time Code                                   Country Name  \
# 0    2000-01-01    YR2000                                  United States
# 1    2000-01-01    YR2000                                 United Kingdom
# 2    2000-01-01    YR2000                                 European Union
# 3    2000-01-01    YR2000                          Europe & Central Asia
# 4    2000-01-01    YR2000                                         Canada
# ..          ...       ...                                            ...
# 216  2016-01-01    YR2016                                  North America
# 217  2016-01-01    YR2016                            East Asia & Pacific
# 218  2016-01-01    YR2016                                     South Asia
# 219  2016-01-01    YR2016  Europe & Central Asia (excluding high income)
# 220  2016-01-01    YR2016    East Asia & Pacific (excluding high income)
#
#     Country Code  gender  employer_pct  industry_pct  service_pct  \
# 0            USA  female      2.240000     23.322001    74.844002
# 1            GBR  female      1.672000     25.167000    73.297997
# 2            EUU  female      2.771487     29.391753    62.666310
# 3            ECS  female      2.444044     27.987970    57.232973
# 4            CAN  female      3.274000     22.475000    74.237000
# ..           ...     ...           ...           ...          ...
# 216          NAC  female      2.202284     18.868170    79.441052
# 217          EAS  female      1.670100     25.101919    53.396054
# 218          SAS  female      0.473881     22.806979    33.317010
# 219          ECA  female      1.342485     26.885360    58.000830
# 220          EAP  female      1.644637     25.109393    51.327372
#
#      agriculture_pct  laborforce_pct  advance_education_pct  \
# 0           2.569000       59.022999              84.552902
# 1           2.171000       53.554001              92.156303
# 2           8.359486       47.703181              82.319485
# 3          14.853220       48.672822               0.000000
# 4           4.478000       58.647999              82.825500
# ..               ...             ...                    ...
# 216         2.356258       56.490389              78.311200
# 217        20.435278       59.558190               0.000000
# 218        38.460843       28.638290               0.000000
# 219        15.100833       49.888776              79.190823
# 220        22.314179       60.520620               0.000000
#
#      intermediate_education_pct  basic_education_pct  wages_and_salaries_pct  \
# 0                     73.584801            51.912498               91.585999
# 1                     86.192497            76.823196               92.141998
# 2                     75.869636            55.798056               85.157378
# 3                      0.000000             0.000000               81.372209
# 4                     77.127098            60.496498               87.636002
# ..                          ...                  ...                     ...
# 216                   65.500088            52.647089               92.255877
# 217                    0.000000             0.000000               60.630319
# 218                    0.000000             0.000000               20.079093
# 219                   78.037187            40.358736               81.531868
# 220                    0.000000             0.000000               57.618533
#
#      Laborforce_pop_total  Population_total  Population_density
# 0            1.467676e+08      2.821624e+08           30.797301
# 1            2.929568e+07      5.889251e+07          243.427909
# 2            2.285269e+08      4.881788e+08          115.084593
# 3            3.976864e+08      8.623041e+08           31.414610
# 4            1.623525e+07      3.076970e+07            3.383699
# ..                    ...               ...                 ...
# 216          1.827033e+08      3.597359e+08           19.721302
# 217          1.257026e+09      2.298727e+09           94.260256
# 218          6.830194e+08      1.766394e+09          370.190760
# 219          1.945188e+08      4.132349e+08           18.266896
# 220          1.127074e+09      2.053299e+09          129.028749
#
# [221 rows x 17 columns]

# %%
# Create df_male
df_male= df3.iloc[:, 0:4]

# Fill in male in gender column
df_male["gender"]=["male" for i in range(len(df_male))]

# Filter out column contain male
male_columns = [column for column in df3.columns if "male" in column and 'female' not in column]
male_df = df3[male_columns]
df_male=pd.concat([df_male, male_df], axis=1)

# Add population info to dataframe
df_male= pd.concat([df_male, df3.iloc[:, 31:34]], axis=1)

df_male.head()
# Out:
#          Time Time Code           Country Name Country Code gender  \
# 0  2000-01-01    YR2000          United States          USA   male
# 1  2000-01-01    YR2000         United Kingdom          GBR   male
# 2  2000-01-01    YR2000         European Union          EUU   male
# 3  2000-01-01    YR2000  Europe & Central Asia          ECS   male
# 4  2000-01-01    YR2000                 Canada          CAN   male
#
#    employer_pct_male  industry_pct_male  service_pct_male  \
# 0           5.507000          12.174000         86.873001
# 1           4.500000          11.953000         87.273003
# 2           6.901186          16.766526         75.843510
# 3           5.616116          17.433606         67.882932
# 4           7.503000          11.167000         86.956001
#
#    agriculture_pct_male  laborforce_pct_male  advance_education_pct_male  \
# 0              0.953000            74.226997                   79.309700
# 1              0.774000            69.938004                   89.738098
# 2              7.389954            65.926715                   80.505325
# 3             14.683327            67.524257                    0.000000
# 4              1.877000            72.126999                   78.557899
#
#    intermediate_education_pct_male  basic_education_pct_male  \
# 0                        65.277100                 40.087200
# 1                        82.661201                 69.078598
# 2                        69.643060                 43.627717
# 3                         0.000000                  0.000000
# 4                        70.049301                 51.746498
#
#    wages_and_salaries_pct_male  Laborforce_pop_total  Population_total  \
# 0                    86.290001           146767599.0       282162411.0
# 1                    83.941002            29295681.0        58892514.0
# 2                    79.046368           228526899.0       488178832.0
# 3                    77.657763           397686380.0       862304086.0
# 4                    80.613998            16235249.0        30769700.0
#
#    Population_density
# 0           30.797301
# 1          243.427909
# 2          115.084593
# 3           31.414610
# 4            3.383699

# %%
# Remove the world male in column tittle to merge with the female data 
df_male.columns = df_male.columns.str.replace("_male", '')
df_male
# Out:
#            Time Time Code                                   Country Name  \
# 0    2000-01-01    YR2000                                  United States
# 1    2000-01-01    YR2000                                 United Kingdom
# 2    2000-01-01    YR2000                                 European Union
# 3    2000-01-01    YR2000                          Europe & Central Asia
# 4    2000-01-01    YR2000                                         Canada
# ..          ...       ...                                            ...
# 216  2016-01-01    YR2016                                  North America
# 217  2016-01-01    YR2016                            East Asia & Pacific
# 218  2016-01-01    YR2016                                     South Asia
# 219  2016-01-01    YR2016  Europe & Central Asia (excluding high income)
# 220  2016-01-01    YR2016    East Asia & Pacific (excluding high income)
#
#     Country Code gender  employer_pct  industry_pct  service_pct  \
# 0            USA   male      5.507000     12.174000    86.873001
# 1            GBR   male      4.500000     11.953000    87.273003
# 2            EUU   male      6.901186     16.766526    75.843510
# 3            ECS   male      5.616116     17.433606    67.882932
# 4            CAN   male      7.503000     11.167000    86.956001
# ..           ...    ...           ...           ...          ...
# 216          NAC   male      5.115226      8.298651    90.789771
# 217          EAS   male      4.522867     19.794388    57.317600
# 218          SAS   male      2.042841     16.654725    23.449449
# 219          ECA   male      3.195645     16.056263    68.813555
# 220          EAP   male      4.485686     20.465076    54.347740
#
#      agriculture_pct  laborforce_pct  advance_education_pct  \
# 0           0.953000       74.226997              79.309700
# 1           0.774000       69.938004              89.738098
# 2           7.389954       65.926715              80.505325
# 3          14.683327       67.524257               0.000000
# 4           1.877000       72.126999              78.557899
# ..               ...             ...                    ...
# 216         0.911576       68.719933              73.751245
# 217        22.888616       76.858791               0.000000
# 218        59.896117       79.528674               0.000000
# 219        15.129961       70.483959              74.263246
# 220        25.187875       77.580146               0.000000
#
#      intermediate_education_pct  basic_education_pct  wages_and_salaries_pct  \
# 0                     65.277100            40.087200               86.290001
# 1                     82.661201            69.078598               83.941002
# 2                     69.643060            43.627717               79.046368
# 3                      0.000000             0.000000               77.657763
# 4                     70.049301            51.746498               80.613998
# ..                          ...                  ...                     ...
# 216                   58.105411            41.589129               87.243744
# 217                    0.000000             0.000000               61.996702
# 218                    0.000000             0.000000               26.813965
# 219                   67.509551            33.789998               78.082421
# 220                    0.000000             0.000000               59.764657
#
#      Laborforce_pop_total  Population_total  Population_density
# 0            1.467676e+08      2.821624e+08           30.797301
# 1            2.929568e+07      5.889251e+07          243.427909
# 2            2.285269e+08      4.881788e+08          115.084593
# 3            3.976864e+08      8.623041e+08           31.414610
# 4            1.623525e+07      3.076970e+07            3.383699
# ..                    ...               ...                 ...
# 216          1.827033e+08      3.597359e+08           19.721302
# 217          1.257026e+09      2.298727e+09           94.260256
# 218          6.830194e+08      1.766394e+09          370.190760
# 219          1.945188e+08      4.132349e+08           18.266896
# 220          1.127074e+09      2.053299e+09          129.028749
#
# [221 rows x 17 columns]

# %%
# Stack df_male and df_female on top of each other
gender_data= pd.concat([df_female, df_male], ignore_index=True)

# %%
gender_data
# Out:
#            Time Time Code                                   Country Name  \
# 0    2000-01-01    YR2000                                  United States
# 1    2000-01-01    YR2000                                 United Kingdom
# 2    2000-01-01    YR2000                                 European Union
# 3    2000-01-01    YR2000                          Europe & Central Asia
# 4    2000-01-01    YR2000                                         Canada
# ..          ...       ...                                            ...
# 437  2016-01-01    YR2016                                  North America
# 438  2016-01-01    YR2016                            East Asia & Pacific
# 439  2016-01-01    YR2016                                     South Asia
# 440  2016-01-01    YR2016  Europe & Central Asia (excluding high income)
# 441  2016-01-01    YR2016    East Asia & Pacific (excluding high income)
#
#     Country Code  gender  employer_pct  industry_pct  service_pct  \
# 0            USA  female      2.240000     23.322001    74.844002
# 1            GBR  female      1.672000     25.167000    73.297997
# 2            EUU  female      2.771487     29.391753    62.666310
# 3            ECS  female      2.444044     27.987970    57.232973
# 4            CAN  female      3.274000     22.475000    74.237000
# ..           ...     ...           ...           ...          ...
# 437          NAC    male      5.115226      8.298651    90.789771
# 438          EAS    male      4.522867     19.794388    57.317600
# 439          SAS    male      2.042841     16.654725    23.449449
# 440          ECA    male      3.195645     16.056263    68.813555
# 441          EAP    male      4.485686     20.465076    54.347740
#
#      agriculture_pct  laborforce_pct  advance_education_pct  \
# 0           2.569000       59.022999              84.552902
# 1           2.171000       53.554001              92.156303
# 2           8.359486       47.703181              82.319485
# 3          14.853220       48.672822               0.000000
# 4           4.478000       58.647999              82.825500
# ..               ...             ...                    ...
# 437         0.911576       68.719933              73.751245
# 438        22.888616       76.858791               0.000000
# 439        59.896117       79.528674               0.000000
# 440        15.129961       70.483959              74.263246
# 441        25.187875       77.580146               0.000000
#
#      intermediate_education_pct  basic_education_pct  wages_and_salaries_pct  \
# 0                     73.584801            51.912498               91.585999
# 1                     86.192497            76.823196               92.141998
# 2                     75.869636            55.798056               85.157378
# 3                      0.000000             0.000000               81.372209
# 4                     77.127098            60.496498               87.636002
# ..                          ...                  ...                     ...
# 437                   58.105411            41.589129               87.243744
# 438                    0.000000             0.000000               61.996702
# 439                    0.000000             0.000000               26.813965
# 440                   67.509551            33.789998               78.082421
# 441                    0.000000             0.000000               59.764657
#
#      Laborforce_pop_total  Population_total  Population_density
# 0            1.467676e+08      2.821624e+08           30.797301
# 1            2.929568e+07      5.889251e+07          243.427909
# 2            2.285269e+08      4.881788e+08          115.084593
# 3            3.976864e+08      8.623041e+08           31.414610
# 4            1.623525e+07      3.076970e+07            3.383699
# ..                    ...               ...                 ...
# 437          1.827033e+08      3.597359e+08           19.721302
# 438          1.257026e+09      2.298727e+09           94.260256
# 439          6.830194e+08      1.766394e+09          370.190760
# 440          1.945188e+08      4.132349e+08           18.266896
# 441          1.127074e+09      2.053299e+09          129.028749
#
# [442 rows x 17 columns]

# %%
# gender_data.to_csv(r'/Users/tinapham/Desktop/lighthouse-data-notes/ProJect/LHL_Midterm_Project/Data/Cleanjobdf/gender_df.csv', index= False)

# %% [markdown]
# ### EDA

# %%
fig_1=sns.pairplot(data=gender_data,
                    hue='gender',
                    kind='reg', 
                    diag_kind='kde',
                    plot_kws={'line_kws':{'color':'red'}})

# %%
# Calculate the correlation of different industry and % of employment
corr=gender_data.corr()
corr
# Out:
# /var/folders/4c/r7kxsc7j67gd7wlqt50rmb100000gn/T/ipykernel_19567/2904926753.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=gender_data.corr()
#                             employer_pct  industry_pct  service_pct  \
# employer_pct                    1.000000     -0.629026     0.617978
# industry_pct                   -0.629026      1.000000    -0.558845
# service_pct                     0.617978     -0.558845     1.000000
# agriculture_pct                -0.503535      0.319885    -0.956907
# laborforce_pct                  0.625679     -0.470012     0.148339
# advance_education_pct           0.208549     -0.358575     0.662423
# intermediate_education_pct      0.172041     -0.309965     0.640562
# basic_education_pct             0.109110     -0.262083     0.557740
# wages_and_salaries_pct          0.277708     -0.127331     0.790640
# Laborforce_pop_total           -0.296592      0.419067    -0.706511
# Population_total               -0.344293      0.391136    -0.775390
# Population_density             -0.418761     -0.034213    -0.462967
#
#                             agriculture_pct  laborforce_pct  \
# employer_pct                      -0.503535        0.625679
# industry_pct                       0.319885       -0.470012
# service_pct                       -0.956907        0.148339
# agriculture_pct                    1.000000       -0.026936
# laborforce_pct                    -0.026936        1.000000
# advance_education_pct             -0.630485       -0.081755
# intermediate_education_pct        -0.618014       -0.110223
# basic_education_pct               -0.529088       -0.135919
# wages_and_salaries_pct            -0.861302       -0.050968
# Laborforce_pop_total               0.632218        0.139758
# Population_total                   0.717099        0.095494
# Population_density                 0.506731       -0.113995
#
#                             advance_education_pct  intermediate_education_pct  \
# employer_pct                             0.208549                    0.172041
# industry_pct                            -0.358575                   -0.309965
# service_pct                              0.662423                    0.640562
# agriculture_pct                         -0.630485                   -0.618014
# laborforce_pct                          -0.081755                   -0.110223
# advance_education_pct                    1.000000                    0.983649
# intermediate_education_pct               0.983649                    1.000000
# basic_education_pct                      0.959715                    0.950471
# wages_and_salaries_pct                   0.572275                    0.566870
# Laborforce_pop_total                    -0.604295                   -0.602715
# Population_total                        -0.617458                   -0.618467
# Population_density                      -0.128568                   -0.124720
#
#                             basic_education_pct  wages_and_salaries_pct  \
# employer_pct                           0.109110                0.277708
# industry_pct                          -0.262083               -0.127331
# service_pct                            0.557740                0.790640
# agriculture_pct                       -0.529088               -0.861302
# laborforce_pct                        -0.135919               -0.050968
# advance_education_pct                  0.959715                0.572275
# intermediate_education_pct             0.950471                0.566870
# basic_education_pct                    1.000000                0.448301
# wages_and_salaries_pct                 0.448301                1.000000
# Laborforce_pop_total                  -0.588976               -0.501796
# Population_total                      -0.597596               -0.589312
# Population_density                    -0.055435               -0.510844
#
#                             Laborforce_pop_total  Population_total  \
# employer_pct                           -0.296592         -0.344293
# industry_pct                            0.419067          0.391136
# service_pct                            -0.706511         -0.775390
# agriculture_pct                         0.632218          0.717099
# laborforce_pct                          0.139758          0.095494
# advance_education_pct                  -0.604295         -0.617458
# intermediate_education_pct             -0.602715         -0.618467
# basic_education_pct                    -0.588976         -0.597596
# wages_and_salaries_pct                 -0.501796         -0.589312
# Laborforce_pop_total                    1.000000          0.984572
# Population_total                        0.984572          1.000000
# Population_density                      0.256721          0.357528
#
#                             Population_density
# employer_pct                         -0.418761
# industry_pct                         -0.034213
# service_pct                          -0.462967
# agriculture_pct                       0.506731
# laborforce_pct                       -0.113995
# advance_education_pct                -0.128568
# intermediate_education_pct           -0.124720
# basic_education_pct                  -0.055435
# wages_and_salaries_pct               -0.510844
# Laborforce_pop_total                  0.256721
# Population_total                      0.357528
# Population_density                    1.000000

# %%
# Create a heat map with correlation data
sns.heatmap(data= corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
import statsmodels.api as sm
y = gender_data[['employer_pct']]
X = gender_data[['industry_pct',
                'service_pct',	
                'agriculture_pct',
                'laborforce_pct',
                'advance_education_pct',
                'basic_education_pct',
                'wages_and_salaries_pct']]
X = sm.add_constant(X)
X.head()
# Out:
#    const  industry_pct  service_pct  agriculture_pct  laborforce_pct  \
# 0    1.0     23.322001    74.844002         2.569000       59.022999
# 1    1.0     25.167000    73.297997         2.171000       53.554001
# 2    1.0     29.391753    62.666310         8.359486       47.703181
# 3    1.0     27.987970    57.232973        14.853220       48.672822
# 4    1.0     22.475000    74.237000         4.478000       58.647999
#
#    advance_education_pct  basic_education_pct  wages_and_salaries_pct
# 0              84.552902            51.912498               91.585999
# 1              92.156303            76.823196               92.141998
# 2              82.319485            55.798056               85.157378
# 3               0.000000             0.000000               81.372209
# 4              82.825500            60.496498               87.636002

# %%
model = sm.OLS(y, X) 
results = model.fit() 
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           employer_pct   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.744
# Method:                 Least Squares   F-statistic:                     184.3
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):          1.07e-125
# Time:                        04:49:28   Log-Likelihood:                -595.41
# No. Observations:                 442   AIC:                             1207.
# Df Residuals:                     434   BIC:                             1240.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -8.8378      2.183     -4.049      0.000     -13.128      -4.548
# industry_pct               0.0756      0.025      2.982      0.003       0.026       0.125
# service_pct                0.1427      0.022      6.465      0.000       0.099       0.186
# agriculture_pct            0.0499      0.022      2.271      0.024       0.007       0.093
# laborforce_pct             0.0633      0.004     15.824      0.000       0.055       0.071
# advance_education_pct      0.0218      0.006      3.645      0.000       0.010       0.034
# basic_education_pct       -0.0398      0.008     -5.267      0.000      -0.055      -0.025
# wages_and_salaries_pct    -0.0438      0.005     -8.283      0.000      -0.054      -0.033
# ==============================================================================
# Omnibus:                       10.761   Durbin-Watson:                   1.759
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):                9.359
# Skew:                           0.287   Prob(JB):                      0.00928
# Kurtosis:                       2.577   Cond. No.                     6.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#import statsmodels.formula.api as smf
#logit = smf.logit("employer_pct ~ sex + service_pct", data=gender_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[234], line 2
#       1 import statsmodels.formula.api as smf
# ----> 2 logit = smf.logit("employer_pct ~ service_pct", data=gender_data)
#
# File ~/anaconda3/envs/LHL_Env/lib/python3.9/site-packages/statsmodels/base/model.py:229, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     223         design_info = design_info.subset(cols)
#     225 kwargs.update({'missing_idx': missing_idx,
#     226                'missing': missing,
#     227                'formula': formula,  # attach formula for unpckling
#     228                'design_info': design_info})
# --> 229 mod = cls(endog, exog, *args, **kwargs)
#     230 mod.formula = formula
#     231 # since we got a dataframe, attach the original
#
# File ~/anaconda3/envs/LHL_Env/lib/python3.9/site-packages/statsmodels/discrete/discrete_model.py:479, in BinaryModel.__init__(self, endog, exog, offset, check_rank, **kwargs)
#     477 if not issubclass(self.__class__, MultinomialModel):
#     478     if not np.all((self.endog >= 0) & (self.endog <= 1)):
# --> 479         raise ValueError("endog must be in the unit interval.")
#     481 if offset is None:
#     482     delattr(self, 'offset')
#
# ValueError: endog must be in the unit interval.

# %%
fig_2=sns.PairGrid(data=df_female)
fig_2.map_upper(sns.scatterplot)      # put in a seaborn function
fig_2.map_lower(sns.kdeplot, fill=True)
fig_2.map_diag(sns.boxplot)
